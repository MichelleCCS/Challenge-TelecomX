# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
datos_telecomx = pd.read_json("TelecomX_Data.json")

# %%
datos_telecomx
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
telecomx_norm_customer = pd.json_normalize(datos_telecomx["customer"])

# %%
telecomx_norm_customer
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
telecomx_norm_phone = pd.json_normalize(datos_telecomx["phone"])

# %%
telecomx_norm_phone
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
telecomx_norm_internet = pd.json_normalize(datos_telecomx["internet"])

# %%
telecomx_norm_internet
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
telecomx_norm_account = pd.json_normalize(datos_telecomx["account"])

# %%
telecomx_norm_account
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %% [markdown]
# #🔧 Transformación

# %%
print(datos_telecomx["customerID"].duplicated().sum())
# Out:
# 0

# %%
print(telecomx_norm_account.isnull().sum())
# Out:
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
print(telecomx_norm_customer.isnull().sum())
# Out:
# gender           0
# SeniorCitizen    0
# Partner          0
# Dependents       0
# tenure           0
# dtype: int64

# %%
print(telecomx_norm_phone.isnull().sum())
# Out:
# PhoneService     0
# MultipleLines    0
# dtype: int64

# %%
print(telecomx_norm_internet.isnull().sum())
# Out:
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %%
print(datos_telecomx["customerID"].isnull().sum())
# Out:
# 0

# %%
print(datos_telecomx["Churn"].isnull().sum())
# Out:
# 0

# %%
print(telecomx_norm_account['Charges.Total'].isnull().sum())
# Out:
# 0

# %%
telecomx_norm_account['Charges.Total'] = telecomx_norm_account['Charges.Total'].str.strip()

# Reemplazar comas por puntos
telecomx_norm_account['Charges.Total'] = telecomx_norm_account['Charges.Total'].str.replace(',', '.')

# Convertir a numérico, manejando errores y valores nulos
telecomx_norm_account['Charges.Total'] = pd.to_numeric(telecomx_norm_account['Charges.Total'], errors='coerce')

# Imputar valores nulos
telecomx_norm_account['Charges.Total'] = telecomx_norm_account['Charges.Total'].fillna(0)  # Imputar con 0

# Convertir a float
telecomx_norm_account['Charges.Total'] = telecomx_norm_account['Charges.Total'].astype(float)

# %%
telecomx_norm_customer['gender'] = telecomx_norm_customer['gender'].str.lower()

# %%
telecomx_norm_customer
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     female              0     Yes        Yes       9
# 1       male              0      No         No       9
# 2       male              0      No         No       4
# 3       male              1     Yes         No      13
# 4     female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  female              0      No         No      13
# 7263    male              0     Yes         No      22
# 7264    male              0      No         No       2
# 7265    male              0     Yes        Yes      67
# 7266    male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
datos_telecomx['Churn'] = datos_telecomx['Churn'].str.lower()

# %%
datos_telecomx['Churn']
# Out:
# 0        no
# 1        no
# 2       yes
# 3       yes
# 4       yes
#        ...
# 7262     no
# 7263    yes
# 7264     no
# 7265     no
# 7266     no
# Name: Churn, Length: 7267, dtype: object

# %%
telecomx_norm_account['Cuentas_Diarias'] = telecomx_norm_account['Charges.Monthly'] / 30
telecomx_norm_account['Cuentas_Diarias']
# Out:
# 0       2.186667
# 1       1.996667
# 2       2.463333
# 3       3.266667
# 4       2.796667
#           ...
# 7262    1.838333
# 7263    2.836667
# 7264    1.676667
# 7265    2.261667
# 7266    1.966667
# Name: Cuentas_Diarias, Length: 7267, dtype: float64

# %%
telecomx_norm_account['Cuentas_Diarias'] = telecomx_norm_account['Cuentas_Diarias'].round(2)
telecomx_norm_account['Cuentas_Diarias']
# Out:
# 0       2.19
# 1       2.00
# 2       2.46
# 3       3.27
# 4       2.80
#         ...
# 7262    1.84
# 7263    2.84
# 7264    1.68
# 7265    2.26
# 7266    1.97
# Name: Cuentas_Diarias, Length: 7267, dtype: float64

# %%
datos_telecomx['Churn'] = datos_telecomx['Churn'].replace({'yes':1, 'no':0})
datos_telecomx['Churn']
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 7262    0
# 7263    1
# 7264    0
# 7265    0
# 7266    0
# Name: Churn, Length: 7267, dtype: object

# %% [markdown]
# #📊 Carga y análisis

# %%
telecomx_norm_account.describe()
# Out:
#        Charges.Monthly  Charges.Total  Cuentas_Diarias
# count      7267.000000    7267.000000      7267.000000
# mean         64.720098    2277.182035         2.157292
# std          30.129572    2268.648587         1.004407
# min          18.250000       0.000000         0.610000
# 25%          35.425000     396.200000         1.180000
# 50%          70.300000    1389.200000         2.340000
# 75%          89.875000    3778.525000         2.995000
# max         118.750000    8684.800000         3.960000

# %%
import numpy as np

# %%
telecomx_norm_customer.describe(exclude=np.number)
# Out:
#        gender Partner Dependents
# count    7267    7267       7267
# unique      2       2          2
# top      male      No         No
# freq     3675    3749       5086

# %%
datos_telecomx = pd.concat([datos_telecomx, telecomx_norm_customer, telecomx_norm_phone, telecomx_norm_internet, telecomx_norm_account], axis=1)

# %%
datos_telecomx.to_json("telecomx_data_norm.json", orient="records")

# %%
telecomex_norm = pd.read_json("telecomx_data_norm.json")

# %%
telecomex_norm
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO     0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE     0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ     1  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF     1  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ     1  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD     0  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN     1  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL     0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB     0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH     0  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
import matplotlib

# %%
from matplotlib import pyplot as plt

# %%
telecomex_norm['Churn'] = pd.to_numeric(telecomex_norm['Churn'])

# Imputar valores NaN con 0 (si es necesario)
telecomex_norm['Churn'] = telecomex_norm['Churn'].fillna(0)

# Convertir a entero
telecomex_norm['Churn'] = telecomex_norm['Churn'].astype(int)

# Calcular la distribución de la variable "Churn"
churn_counts = telecomex_norm['Churn'].value_counts().sort_index()

# Crear el gráfico de pastel
plt.pie(churn_counts, labels=['Clientes que permanecen', 'Clientes que se dieron de baja'], autopct='%1.1f%%', startangle=90)

# Agregar un título al gráfico
plt.title('Distribución de Evasión')

# Asegurar que el círculo se vea como un círculo
plt.axis('equal')

# Mostrar el gráfico
plt.show()

# %%
evasion_genero = telecomex_norm.loc[telecomex_norm['Churn'] == 1, 'gender']

# %%
import matplotlib.pyplot as plt

# Contar la frecuencia de cada género
conteo_genero = evasion_genero.value_counts()

# Crear el gráfico de barras
conteo_genero.plot(kind='bar', color='skyblue')

# Añadir etiquetas y título
plt.title('Evasión por Género')
plt.xlabel('Género')
plt.ylabel('Número de Clientes Evadidos')

# Mostrar el gráfico
plt.show()

# %%
evasion_tipo_contrato = telecomex_norm.loc[telecomex_norm['Churn'] == 1, 'Contract']

# %%
import matplotlib.pyplot as plt
conteo_contrato = evasion_tipo_contrato.value_counts()
conteo_contrato.plot(kind='bar', color='pink')
plt.title('Evasión por Tipo de Contrato')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Número de Clientes Evadidos')
plt.show()

# %%
evasion_tipo_de_pago = telecomex_norm.loc[telecomex_norm['Churn'] == 1, 'PaymentMethod']

# %%
import matplotlib.pyplot as plt
conteo_tipo_de_pago = evasion_tipo_de_pago.value_counts()
conteo_tipo_de_pago.plot(kind='bar', color='orange')
plt.title('Evasión por Tipo de Pago')
plt.xlabel('Tipo de Pago')
plt.ylabel('Número de Clientes Evadidos')
plt.show()

# %%
total_gastado_por_churn = telecomex_norm.groupby('Churn')['Charges.Total'].sum()

print(total_gastado_por_churn)
# Out:
# Churn
# 0    13685354.95
# 1     2862926.90
# Name: Charges.Total, dtype: float64

# %%
total_gastado_por_churn.plot(kind='bar', color='green')
plt.title('Total gastado por clientes')
plt.xlabel('Número de Clientes Permanentes y Número de Clientes Evadidos')
plt.ylabel('Total gastado')
plt.show()

# %%
gasto_mensual_por_churn = telecomex_norm.groupby('Churn')['Charges.Monthly'].sum()

print(gasto_mensual_por_churn)
# Out:
# Churn
# 0    331190.10
# 1    139130.85
# Name: Charges.Monthly, dtype: float64

# %%
gasto_mensual_por_churn.plot(kind='bar', color='purple')
plt.title('Total mensual gastado por clientes')
plt.xlabel('Número de Clientes Permanentes y Número de Clientes Evadidos')
plt.ylabel('Gasto mensual')
plt.show()

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ##🔹 Introducción
# En este proyecto se analizan los datos de clientes de TelecomX LATAM con el objetivo de identificar patrones de evasión de clientes (churn) y proponer acciones para reducirla. La evasión de clientes representa una pérdida importante para las empresas de telecomunicaciones, por lo que entender sus causas es esencial para retener usuarios y mejorar los ingresos.
#
# ##🔹 Limpieza y Tratamiento de Datos
# El proceso de preparación de datos incluyó los siguientes pasos:
#
# Importación del archivo JSON con datos de clientes.
#
# Normalización de columnas anidadas: customer, phone, internet, account.
#
# Conversión de variables categóricas a minúsculas para un tratamiento homogéneo.
#
# Reemplazo de valores de Churn (yes → 1, no → 0) para facilitar análisis numéricos.
#
# Conversión de Charges.Total a tipo numérico, limpiando símbolos y formatos.
#
# Creación de una variable derivada: Cuentas_Diarias (gasto mensual / 30).
#
# Verificación de valores nulos y su imputación si fue necesario.
#
# ##🔹 Análisis Exploratorio de Datos
# Se realizaron diversos análisis estadísticos y visuales para detectar factores asociados a la evasión:
#
# ## 📊 Distribución General del Churn
# Se generó un gráfico de pastel que mostró que aproximadamente el 26.3% de los clientes se han dado de baja.
#
# ## 📊 Evasión por Género
# El género masculino tuvo ligeramente mayor tasa de evasión en comparación con el femenino.
#
# ## 📊 Evasión por Tipo de Contrato
# La mayoría de los clientes evadidos tenían contrato "Month-to-month" (mes a mes), indicando una relación menos comprometida.
#
# ## 📊 Evasión por Tipo de Pago
# El método de pago "Electronic check" fue el más común entre los clientes que se dieron de baja, lo que puede señalar fricción o desconfianza.
#
# ## 📊 Gasto Total Acumulado
# Clientes activos han gastado $13.7 millones.
#
# Clientes evadidos solo $2.8 millones.
#
# ## 📊 Gasto Mensual Promedio
# Los clientes activos generan mayor ingreso mensual en conjunto, aunque muchos evadidos también tenían cargos mensuales altos.
#
# ##🔹 Conclusiones e Insights
# El tipo de contrato es un factor decisivo: los clientes con contratos mes a mes son más propensos a abandonar el servicio.
#
# El método de pago también influye: quienes usan métodos electrónicos muestran mayor evasión.
#
# El nivel de gasto no garantiza permanencia: hay clientes con cargos altos que se han dado de baja.
#
# La evasión afecta tanto a clientes nuevos como a algunos de larga duración, pero es más frecuente en los de menor permanencia (tenure).
#
# ##🔹 Recomendaciones
# Incentivar contratos a largo plazo mediante descuentos o beneficios exclusivos.
#
# Ofrecer canales de pago más confiables y transparentes que generen seguridad (por ejemplo, pagos automáticos o vía apps móviles).
#
# Identificar y contactar preventivamente a clientes con características similares a los que evadieron (perfil de contrato, pago, gasto).
#
# Mejorar la experiencia digital para clientes con servicios de internet y telefonía, reduciendo problemas técnicos y reforzando el soporte.
#
# ##🔚 Cierre
# Este análisis proporciona una base sólida para diseñar campañas de retención y mejorar la fidelización en TelecomX LATAM. Implementar estas acciones estratégicas podría reducir significativamente la evasión y aumentar el valor de vida de cada cliente.
